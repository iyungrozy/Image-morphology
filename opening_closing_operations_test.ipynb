# %% [markdown]
# <a href="https://colab.research.google.com/github/iyungrozy/Image-morphology/blob/main/opening_closing_operations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Nyerah
#
# pusing nyari kernel yang pas pak :)<br>
# berikanlah hambamu ini pencerahan hehehe

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
# Membaca gambar
img = cv2.imread('tatasurya.jpg', 0)

# %%
# Menampilkan gambar asli
plt.subplot(131), plt.imshow(img, 'gray'), plt.title('Original Image')
# Out:
# (<Axes: title={'center': 'Original Image'}>,
# ...
#  Text(0.5, 1.0, 'Original Image'))

# %%
# Membuat kernel untuk operasi opening dan closing
kernel = np.ones((5,5),np.uint8)

# %%
# Opening
opening = cv2.morphologyEx(img, cv2.MORPH_OPEN, kernel)

# %%
# Menampilkan hasil opening
plt.subplot(132), plt.imshow(opening, 'gray'), plt.title('Opening')
# Out:
# (<Axes: title={'center': 'Opening'}>,
# ...
#  Text(0.5, 1.0, 'Opening'))

# %%
# Menampilkan hasil closing
plt.subplot(133), plt.imshow(closing, 'gray'), plt.title('Closing')

plt.show()

# %%
# Menampilkan hasil closing
plt.subplot(133), plt.imshow(closing, 'gray'), plt.title('Closing')

plt.show()
